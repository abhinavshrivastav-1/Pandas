# %%
import pandas as pd

df = pd.read_csv('C:/Users/shriv/Downloads/WORK/sampledata (1).csv')

print(df.head(5))
# Out:
#   Index       State    Y2002    Y2003    Y2004    Y2005    Y2006    Y2007  \
# 0     A     Alabama  1296530  1317711  1118631  1492583  1107408  1440134
# 1     A      Alaska  1170302  1960378  1818085  1447852  1861639  1465841
# 2     A     Arizona  1742027  1968140  1377583  1782199  1102568  1109382
# 3     A    Arkansas  1485531  1994927  1119299  1947979  1669191  1801213
# 4     C  California  1685349  1675807  1889570  1480280  1735069  1812546
#
#      Y2008    Y2009    Y2010    Y2011    Y2012    Y2013    Y2014    Y2015
# 0  1945229  1944173  1237582  1440756  1186741  1852841  1558906  1916661
# 1  1551826  1436541  1629616  1230866  1512804  1985302  1580394  1979143
# 2  1752886  1554330  1300521  1130709  1907284  1363279  1525866  1647724
# 3  1188104  1628980  1669295  1928238  1216675  1591896  1360959  1329341
# 4  1487315  1663809  1624509  1639670  1921845  1156536  1388461  1644607

# %%
#### Read Headers
df.columns
# Out:
# Index(['Index', 'State', 'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007',
#        'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014', 'Y2015'],
#       dtype='object')

# %%
# sorting in ascending
df.sort_values(['Y2002', 'Y2003'], ascending=[1,0])

df
# Out:
#    Index                 State    Y2002    Y2003    Y2004    Y2005    Y2006  \
# 0      A               Alabama  1296530  1317711  1118631  1492583  1107408
# 1      A                Alaska  1170302  1960378  1818085  1447852  1861639
# 2      A               Arizona  1742027  1968140  1377583  1782199  1102568
# 3      A              Arkansas  1485531  1994927  1119299  1947979  1669191
# 4      C            California  1685349  1675807  1889570  1480280  1735069
# 5      C              Colorado  1343824  1878473  1886149  1236697  1871471
# 6      C           Connecticut  1610512  1232844  1181949  1518933  1841266
# 7      D              Delaware  1330403  1268673  1706751  1403759  1441351
# 8      D  District of Columbia  1111437  1993741  1374643  1827949  1803852
# 9      F               Florida  1964626  1468852  1419738  1362787  1339608
# 10     G               Georgia  1929009  1541565  1810773  1779091  1326846
# ...

# %%
#change in data

df['Index'] = df['Y2002'] + df['Y2003'] + df['Y2004'] + df['Y2005'] + df['Y2006'] + df['Y2007']

# df = df.drop(columns=['Y2005'])

df['Total'] = df.iloc[:, 4:10].sum(axis=1)

cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]]+cols[4:12]]

df.head(5)
# Out:
#       Index       State    Y2002    Y2003     Total    Y2004    Y2005  \
# 0   7772997     Alabama  1296530  1317711   9048158  1118631  1492583
# 1   9724097      Alaska  1170302  1960378   9581784  1818085  1447852
# 2   9081899     Arizona  1742027  1968140   8678948  1377583  1782199
# 3  10018140    Arkansas  1485531  1994927   9354766  1119299  1947979
# 4  10278621  California  1685349  1675807  10068589  1889570  1480280
#
#      Y2006    Y2007    Y2008    Y2009    Y2010    Y2011
# 0  1107408  1440134  1945229  1944173  1237582  1440756
# 1  1861639  1465841  1551826  1436541  1629616  1230866
# 2  1102568  1109382  1752886  1554330  1300521  1130709
# 3  1669191  1801213  1188104  1628980  1669295  1928238
# 4  1735069  1812546  1487315  1663809  1624509  1639670

# %%
# saving the data
df.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

df.to_csv('modified.txt', index=False, sep='\t')

# %%
#filtered data'
new_df = df.loc[(df['State'] == 'Alaska')]


new_df.reset_index(drop=True, inplace=True)

new_df

new_df.to_csv('filtered.csv')

# %%
df = pd.read_csv('modified.csv')

df['count'] = 1

#This will give us the count of each type 1 parameter

df.groupby(['State']).count()['count']

#df.groupby(['State']).sum()
# Out:
# State
# Alabama                 1
# Alaska                  1
# Arizona                 1
# Arkansas                1
# California              1
# Colorado                1
# Connecticut             1
# Delaware                1
# District of Columbia    1
# Florida                 1
# Georgia                 1
# Hawaii                  1
# Idaho                   1
# Illinois                1
# Indiana                 1
# Iowa                    1
# Kansas                  1
# Kentucky                1
# Louisiana               1
# Maine                   1
# Maryland                1
# Massachusetts           1
# Michigan                1
# Minnesota               1
# Mississippi             1
# Missouri                1
# Montana                 1
# Nebraska                1
# Nevada                  1
# New Hampshire           1
# New Jersey              1
# New Mexico              1
# New York                1
# North Carolina          1
# North Dakota            1
# ...

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('modified.csv', chunksize=5):
    results = df.groupby(['Y2002']).count()
    
    new_df = pd.concat([new_df, results])
    print(new_df)
# Out:
#         Index State Y2002 Y2003 Total Y2004 Y2005 Y2006 Y2007 Y2008 Y2009  \
# 1170302     1     1   NaN     1     1     1     1     1     1     1     1
# 1296530     1     1   NaN     1     1     1     1     1     1     1     1
# 1485531     1     1   NaN     1     1     1     1     1     1     1     1
# 1685349     1     1   NaN     1     1     1     1     1     1     1     1
# 1742027     1     1   NaN     1     1     1     1     1     1     1     1
#
#         Y2010 Y2011 count
# 1170302     1     1   NaN
# 1296530     1     1   NaN
# 1485531     1     1   NaN
# 1685349     1     1   NaN
# 1742027     1     1   NaN
#         Index State Y2002 Y2003 Total Y2004 Y2005 Y2006 Y2007 Y2008 Y2009  \
# 1170302     1     1   NaN     1     1     1     1     1     1     1     1
# 1296530     1     1   NaN     1     1     1     1     1     1     1     1
# 1485531     1     1   NaN     1     1     1     1     1     1     1     1
# ...
